# %%
# Project setup
import sys
import os

PROJECT_ROOT = os.path.abspath("..")
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

# %% [markdown]
# # Imports

# %%
from src.data.binance_client import BinanceClient
from src.features.market_features import add_market_features
from src.visualization.visualization_utils import plot_market_overview

# %% [markdown]
# # Data Loading

# %%
client = BinanceClient()
df = client.get_klines(symbol="BTCUSDT", interval="1d", limit=180)

df.head()
# Out:
#    open_time       open       high        low      close       volume  \
# 0 2025-10-31  108322.87  111190.00  108275.28  109608.01  21518.20439
# 1 2025-11-01  109608.01  110564.49  109394.81  110098.10   7378.50431
# 2 2025-11-02  110098.10  111250.01  109471.34  110540.68  12107.00087
# 3 2025-11-03  110540.69  110750.00  105306.56  106583.04  28681.18779
# 4 2025-11-04  106583.05  107299.00   98944.36  101497.22  50534.87376
#
#                close_time  quote_asset_volume  num_trades  taker_buy_base  \
# 0 2025-10-31 23:59:59.999        2.361590e+09     5256872     10798.53938
# 1 2025-11-01 23:59:59.999        8.123892e+08     1994214      3406.68401
# 2 2025-11-02 23:59:59.999        1.336871e+09     2652188      5921.86453
# 3 2025-11-03 23:59:59.999        3.076007e+09     7074546     12847.08574
# 4 2025-11-04 23:59:59.999        5.197698e+09     9099609     23388.99033
#
#    taker_buy_quote ignore
# 0     1.185034e+09      0
# 1     3.751270e+08      0
# ...

# %% [markdown]
# # Features
#
# Generating relevant features such as average daily price, relative volatility and volume baseline

# %%
df = add_market_features(df)

# %% [markdown]
# # Plotting
#
# Hypothesis: VWAP and volume spikes to be aligned

# %%
fig, ax1, ax2, ax3 = plot_market_overview(df, title="BTC/USDT Daily Price Overview")
display(fig)

# %% [markdown]
# Observations:
# - Mid-November and early Febraury drops in BTC price matches increases in BTC volume transacted
# - Mid-November and early Febraury volume spikes are significantly above the 30-day volume baseline
